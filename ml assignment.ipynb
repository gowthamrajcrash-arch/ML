# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import scipy.cluster.hierarchy as sch

# -----------------------------
# 1. Load Dataset
# -----------------------------
data = pd.read_csv("customers.csv")

# Select features (edit as needed)
X = data[['Annual_Income', 'Spending_Score']]

# -----------------------------
# 2. Data Scaling
# -----------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# -----------------------------
# 3. K-Means Clustering
# -----------------------------
kmeans = KMeans(n_clusters=5, random_state=42)
data['KMeans_Cluster'] = kmeans.fit_predict(X_scaled)

# -----------------------------
# 4. Hierarchical Clustering
# -----------------------------
# Dendrogram
plt.figure(figsize=(8, 5))
sch.dendrogram(sch.linkage(X_scaled, method='ward'))
plt.title("Dendrogram (Hierarchical Clustering)")
plt.xlabel("Customers")
plt.ylabel("Distance")
plt.show()

# Apply Hierarchical Clustering
hc = AgglomerativeClustering(n_clusters=5, linkage='ward')
data['Hierarchical_Cluster'] = hc.fit_predict(X_scaled)

# -----------------------------
# 5. Visualization
# -----------------------------
plt.figure(figsize=(12, 5))

# K-Means Plot
plt.subplot(1, 2, 1)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1],
            c=data['KMeans_Cluster'], cmap='viridis')
plt.title("K-Means Clustering")
plt.xlabel("Income (scaled)")
plt.ylabel("Spending Score (scaled)")

# Hierarchical Plot
plt.subplot(1, 2, 2)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1],
            c=data['Hierarchical_Cluster'], cmap='rainbow')
plt.title("Hierarchical Clustering")
plt.xlabel("Income (scaled)")
plt.ylabel("Spending Score (scaled)")

plt.tight_layout()
plt.show()

# -----------------------------
# 6. Save Results
# -----------------------------
data.to_csv("segmented_customers.csv", index=False)

print("Clustering completed. Results saved to segmented_customers.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3507/3941396631.py in <cell line: 0>()
#       9 # 1. Load Dataset
#      10 # -----------------------------
# ---> 11 data = pd.read_csv("customers.csv")
#      12
#      13 # Select features (edit as needed)
#
# ...

# %%
import os

file_name = 'customers.csv'
if os.path.exists(file_name):
    print(f"'{file_name}' found. You can now re-run the analysis cell (cell 6k4XIrKceV6y).")
else:
    print(f"'{file_name}' not found. Please upload the 'customers.csv' file using the file explorer on the left sidebar (click the folder icon, then the upload icon) and then re-run this cell.")
# Out:
# 'customers.csv' not found. Please upload the 'customers.csv' file using the file explorer on the left sidebar (click the folder icon, then the upload icon) and then re-run this cell.
